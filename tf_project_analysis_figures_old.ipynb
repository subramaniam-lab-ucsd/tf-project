# %% [markdown]
# # Transcription Factor Project - KOLF2.1J Dataset Downstream Analysis Old Figures
# **Robin Anwyl, UCSD Subramaniam Lab**
#
# **Goal:** Analyze the KOLF2.1J Perturb-seq dataset from the Nourreddine et al. (2024) preprint to investigate the effects of transcription factor knockdowns (TF KDs)
#
# **Guiding Questions:** What do TF KD effects reveal about:
# * the transcriptional regulatory network of hiPSCs?
# * TF crosstalk and co-regulation?
# * cell lineage?
# * how TFs influence chromatin remodeling?

# %% [markdown]
# # GSEA

# %% [markdown]
# ## Top terms per cluster

# %%
filepath = "/home/ranwyl/output_files_tf_project/KOLF_GSEA_results_6-21-26.pkl"
kolf_gsea_results = pd.read_pickle(filepath)
kolf_gsea_results_up = kolf_gsea_results[kolf_gsea_results["NES"] > 0]
kolf_gsea_results_down = kolf_gsea_results[kolf_gsea_results["NES"] < 0]

# %%
# Terms shared by 20% or more of TF KDs
kolf_generic_terms_20 = set(kolf_kd_shared_gsea_terms[
    kolf_kd_shared_gsea_terms["# TF KDs"] >= 36]["Term"])
print(len(kolf_generic_terms_20))
# Terms shared by 10% or more of TF KDs
kolf_generic_terms_10 = set(kolf_kd_shared_gsea_terms[
    kolf_kd_shared_gsea_terms["# TF KDs"] >= 18]["Term"])
print(len(kolf_generic_terms_10))
# Out:
# 119
# 177

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=0, 
                    title="KOLF CL0 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.25, figsize=(6,10),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=1, 
                    title="KOLF CL1 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.25, figsize=(6,10),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=2, 
                    title="KOLF CL2 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(5,6),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=3, 
                    title="KOLF CL3 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(3,4),
                    min_enriched_per_kd=1)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=4, 
                    title="KOLF CL4 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,7),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=5, 
                    title="KOLF CL5 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,6),
                    min_enriched_per_kd=1)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=6, 
                    title="KOLF CL6 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,4),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=7, 
                    title="KOLF CL7 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,6),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=8, 
                    title="KOLF CL8 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(5,15),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=9, 
                    title="KOLF CL9 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(2,3),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=10, 
                    title="KOLF CL10 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,8),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=11, 
                    title="KOLF CL11 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(2,3),
                    min_enriched_per_kd=2)

# %%
_ = plot_gsea_heatmap(kolf_gsea_results_up, cluster=12, 
                    title="KOLF CL12 GSEA Positively Enriched Terms",
                    term_blacklist=kolf_generic_terms_20,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,8),
                    min_enriched_per_kd=2)

# %% [markdown]
# ## Leiden Cluster 8

# %%
filepath = "/home/ranwyl/output_files_tf_project/KOLF_GSEA_results_interest30_perm10k_7-1-26.csv"
kolf_gsea_results_10k_interest = pd.read_csv(filepath, header=0, index_col=0)

# %%
cl8_tf_kd_labels = ['POU5F1 KD', 'POU5F1B KD', 'ZNF521 KD', 'ZNF396 KD', 'POU3F2 KD',
              'PHF20 KD', 'RBPJ KD', 'SP1 KD', 'HNF4A KD', 'DOT1L KD', 'ETV3L KD']

# %%
# Terms shared by 10% or more of TF KDs
kolf_generic_terms = set(kolf_kd_shared_gsea_terms[
    kolf_kd_shared_gsea_terms["# TF KDs"] >= 18]["Term"])

# %%
plur_terms = ['POU5F1 CHEA', 'NANOG CHEA', 'SOX2 CHEA', 'SALL4 CHEA', 
'Transcriptional Regulation of Pluripotent Stem Cells']
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest, cluster=8, 
                    title="KOLF CL8 GSEA Pluripotency Terms",
                    terms=plur_terms, kd_col="TF KD", cbar_size=0.75,
                    figsize=(6,3), kd_order=cl8_tf_kd_labels)

# %%
cl8_tf_kd_labels_interest = ['POU5F1 KD', 'POU5F1B KD', 'ZNF521 KD', 'ZNF396 KD', 'POU3F2 KD',
                            'PHF20 KD']

# %%
cl8_blacklist = kolf_generic_terms | {"SUZ12 ENCODE"}
kolf_gsea_results_10k_interest_up = kolf_gsea_results_10k_interest[
    kolf_gsea_results_10k_interest["NES"] > 0]
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest_up, cluster=8, 
                    title="KOLF CL8 GSEA Positively Enriched Terms",
                    kd_order=cl8_tf_kd_labels_interest,
                    term_blacklist=cl8_blacklist,
                    n_terms=20, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(6,10),
                    min_enriched_per_kd=2)

# %%
cl8_neural_terms = {'Axon Guidance (GO:0007411)', 'Neuron Projection Guidance (GO:0097485)', 
                       'Axonogenesis (GO:0007409)', 'Brain Development (GO:0007420)', 
                       'Regulation of Neuron Differentiation (GO:0045664)', 
                       'Neural Crest Cell Migration (GO:0001755)', 
                       'Neural Crest Cell Development (GO:0014032)', 'AXON GUIDANCE', 
                       'Positive Regulation of Axon Extension (GO:0045773)', 
                       'Neuron Differentiation (GO:0030182)', 
                       'EPHA-mediated Growth Cone Collapse', 
                       'Positive Regulation of Neuron Differentiation (GO:0045666)', 
                       'Generation of Neurons (GO:0048699)', 
                       'Regulation of Neuron Migration (GO:2001222)', 
                       'Neuron Projection Morphogenesis (GO:0048812)',
                       'Regulation of Neurogenesis (GO:0050767)',
                       'Synapse Organization (GO:0050808)'}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest, cluster=8, 
                    title="KOLF Cluster 8 GSEA - Neural",
                    kd_order=cl8_tf_kd_labels_interest,
                    terms=cl8_neural_terms,
                    n_terms=30, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,6))

# %%
# Endoderm term
# 'Endoderm Formation (GO:0001706)',

# Cross-layer terms
# 'Epithelial Cell Development (GO:0002064)', 
# 'Positive Regulation of Morphogenesis of an Epithelium (GO:1905332)',
# 'Gland Development (GO:0048732)',

# %%
cl8_ectoderm_terms = {
    'Eye Development (GO:0001654)', 'Camera-Type Eye Development (GO:0043010)', 
    'Visual System Development (GO:0150063)', 'Eye Morphogenesis (GO:0048592)',
    'Sensory Organ Development (GO:0007423)', 'Inner Ear Morphogenesis (GO:0042472)',
}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest, cluster=8, 
                    title="KOLF CL8 GSEA - Ectoderm",
                    kd_order=cl8_tf_kd_labels_interest,
                    terms=cl8_ectoderm_terms,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    figsize=(4,3))

# %%
cl8_mesoderm_terms = {
    'Regulation of Chondrocyte Differentiation (GO:0032330)', 
    'Connective Tissue Development (GO:0061448)', 'Cartilage Development (GO:0051216)',
    'Skeletal System Development (GO:0001501)',
    'Positive Regulation of Osteoblast Differentiation (GO:0045669)', 
    'Positive Regulation of Ossification (GO:0045778)', 
    'Positive Regulation of Bone Mineralization (GO:0030501)', 
    'Embryonic Skeletal System Development (GO:0048706)',
    'RUNX2 Regulates Osteoblast Differentiation', 'RUNX2 Regulates Bone Development',
    'Embryonic Limb Morphogenesis (GO:0030326)', 'Myogenesis', 
    'Fat Cell Differentiation (GO:0045444)',  
    'Kidney Development (GO:0001822)', 'Angiogenesis', 
    'Limb Development (GO:0060173)',
    'Aortic Valve Morphogenesis (GO:0003180)', 
    'Heart Development (GO:0007507)', 'Striated Muscle Tissue Development (GO:0014706)',
    'Regulation of Sprouting Angiogenesis (GO:1903670)', 'Gonad Development (GO:0008406)',
}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest, cluster=8, 
                    title="KOLF CL8 GSEA - Mesoderm",
                    kd_order=cl8_tf_kd_labels_interest,
                    terms=cl8_mesoderm_terms,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,7))

# %%
cl8_signaling_terms_up = {
    'Regulation of Smoothened Signaling Pathway (GO:0008589)', 
    'HEDGEHOG SIGNALING PATHWAY', 'WNT SIGNALING PATHWAY',
    'Non-Canonical Wnt Signaling Pathway (GO:0035567)', 
    'Response to Transforming Growth Factor Beta (GO:0071559)', 
    'Notch Signaling', 'Regulation of Wnt Signaling Pathway (GO:0030111)', 
    'TGF-beta Signaling',
    'Ephrin Receptor Signaling Pathway (GO:0048013)',
    'Wnt-beta Catenin Signaling',
}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest[kolf_gsea_results_10k_interest["NES"] > 0], cluster=8, 
                    title="KOLF CL8 GSEA - Signaling Up",
                    kd_order=cl8_tf_kd_labels_interest,
                    terms=cl8_signaling_terms_up,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,4))

# %%
cl8_signaling_terms_down = {
    'Interferon Alpha Beta Signaling', 
    'Response to Interferon-Beta (GO:0035456)',
    'Response to Type II Interferon (GO:0034341)',
    'FCERI Mediated NF-kB Activation', 'TCR Signaling',
    'Inactivation of CSF3 (G-CSF) Signaling', 'Interleukin-12 Signaling', 
    'Interleukin-12 Family Signaling', 'Interleukin-1 Signaling', 'Downstream TCR Signaling',
    'Gene and Protein Expression by JAK-STAT Signaling After Interleukin-12 Stimulation',
    'TNFR2 Non-Canonical NF-kB Pathway', 'DDX58 IFIH1-mediated Induction of Interferon-Alpha Beta',
}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest[kolf_gsea_results_10k_interest["NES"] < 0], cluster=8, 
                    title="KOLF CL8 GSEA - Signaling Down",
                    kd_order=cl8_tf_kd_labels_interest,
                    terms=cl8_signaling_terms_down,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,6))

# %%
cl8_emt_ecm_terms = {'Elastic Fibre Formation', 
                    'Molecules Associated With Elastic Fibres', 
                    'CELL ADHESION MOLECULE (CAM) INTERACTION', 
                    'Cell-Cell Adhesion via Plasma-Membrane Adhesion Molecules (GO:0098742)', 
                    'ECM Proteoglycans', 
                    'Cell Junction Assembly (GO:0034329)', 
                    'Homophilic Cell Adhesion via Plasma Membrane Adhesion Molecules (GO:0007156)',
                    'Epithelial Mesenchymal Transition', 
                    'Regulation of Epithelial to Mesenchymal Transition (GO:0010717)',
                    'Mesenchymal Cell Migration (GO:0090497)'}
_ = plot_gsea_heatmap(kolf_gsea_results_10k_interest, cluster=8, 
                    title="KOLF CL8 GSEA - EMT + ECM Remodeling",
                    kd_order=['POU5F1 KD', 'POU5F1B KD', 'ZNF521 KD', 'ZNF396 KD', 'POU3F2 KD', 'PHF20 KD', 'RBPJ KD'],
                    terms=cl8_emt_ecm_terms,
                    n_terms=50, kd_col="TF KD", xlabel="TF KD",
                    cbar_size=0.5, figsize=(4,4))

# %% [markdown]
# # TF activity inference

# %% [markdown]
# ## All clusters

# %% [markdown]
# ### TF activity

# %%
signif_tfs_per_cluster_kolf = pd.DataFrame(tf_acts_df_clusters_kolf.notna().sum(axis=1), 
                                           columns=["# significant TFs"])
signif_tfs_per_cluster_kolf
# Out:
#             # significant TFs
# Cluster 0                  10
# Cluster 1                   2
# Cluster 2                   2
# Cluster 3                   3
# Cluster 4                   8
# Cluster 5                  11
# Cluster 6                   4
# Cluster 7                   8
# Cluster 8                  52
# Cluster 9                   3
# Cluster 10                  3
# Cluster 11                  1
# Cluster 12                  3

# %%
# All clusters except 8
tf_acts_df_clusters_kolf[~tf_acts_df_clusters_kolf.index.isin(['Cluster 8'])].dropna(axis=1, thresh=1).T
# Out:
#         Cluster 0  Cluster 1  Cluster 2  Cluster 3  Cluster 4  Cluster 5  \
# E2F4    -3.385629        NaN        NaN        NaN        NaN        NaN
# HSF1    -3.882529        NaN        NaN        NaN        NaN        NaN
# HSF2    -4.365313        NaN        NaN        NaN        NaN        NaN
# KLF7     3.513472        NaN        NaN        NaN        NaN        NaN
# MYC    -13.247385  -8.746367  -7.710453 -10.544752 -10.676360  -9.895924
# SALL2    3.392642        NaN        NaN        NaN        NaN        NaN
# SP1     -4.115345        NaN        NaN  -4.638969  -4.703323  -3.703307
# TEAD1   -3.451880        NaN        NaN        NaN        NaN        NaN
# ZBTB4   -6.229181  -6.124379  -4.797347  -3.926093  -5.157701  -4.332960
# ZNF76   -3.709091        NaN        NaN        NaN        NaN        NaN
# CEBPD         NaN        NaN        NaN        NaN  -4.148328        NaN
# GBX2          NaN        NaN        NaN        NaN  -4.109175        NaN
# ...

# %%
# Clusters with at least 5 enriched TFs
tf_acts_df_clusters_kolf.dropna(axis=0, thresh=5)
# Out:
#                E2F4      HSF1      HSF2      KLF7        MYC     SALL2  \
# Cluster 0 -3.385629 -3.882529 -4.365313  3.513472 -13.247385  3.392642
# Cluster 4       NaN       NaN       NaN       NaN -10.676360       NaN
# Cluster 5       NaN       NaN       NaN       NaN  -9.895924       NaN
# Cluster 7 -3.552584 -3.457827       NaN       NaN  -8.933206       NaN
# Cluster 8       NaN -3.751585       NaN       NaN  -6.451238       NaN
#
#                 SP1    TEAD1     ZBTB4     ZNF76  ...      SOX9      SPI1  \
# Cluster 0 -4.115345 -3.45188 -6.229181 -3.709091  ...       NaN       NaN
# Cluster 4 -4.703323      NaN -5.157701       NaN  ...       NaN       NaN
# Cluster 5 -3.703307      NaN -4.332960       NaN  ...       NaN       NaN
# Cluster 7 -3.566591      NaN -3.900796       NaN  ...       NaN       NaN
# Cluster 8       NaN      NaN -3.556380       NaN  ...  4.259131 -3.319768
#
#                TAF1      TET1    TWIST2     WWTR1    ZBTB18  JUN  GLI1  IRF8
# ...

# %%
# TFs enriched in at least 2 clusters
tf_acts_df_kolf_shared = tf_acts_df_clusters_kolf.dropna(axis=1, thresh=2)
tf_acts_df_kolf_shared
# Out:
#                 E2F4      HSF1        MYC       SP1     ZBTB4     NR5A2
# Cluster 0  -3.385629 -3.882529 -13.247385 -4.115345 -6.229181       NaN
# Cluster 1        NaN       NaN  -8.746367       NaN -6.124379       NaN
# Cluster 2        NaN       NaN  -7.710453       NaN -4.797347       NaN
# Cluster 3        NaN       NaN -10.544752 -4.638969 -3.926093       NaN
# Cluster 4        NaN       NaN -10.676360 -4.703323 -5.157701 -3.468958
# Cluster 5        NaN       NaN  -9.895924 -3.703307 -4.332960       NaN
# Cluster 6        NaN       NaN  -9.828094 -3.869545 -4.497147       NaN
# Cluster 7  -3.552584 -3.457827  -8.933206 -3.566591 -3.900796       NaN
# Cluster 8        NaN -3.751585  -6.451238       NaN -3.556380 -3.259838
# Cluster 9  -3.919536       NaN  -7.548939       NaN -3.775434       NaN
# Cluster 10       NaN       NaN  -6.693433 -3.878490       NaN       NaN
# Cluster 11       NaN       NaN  -6.225319       NaN       NaN       NaN
# ...

# %%
plot_tf_pw_activity_heatmap(tf_acts_df_kolf_shared, 
                            title="KOLF CollecTRI Inferred TF Activities (Shared)",
                            xlabel="Leiden Cluster", ylabel="Transcription Factor", figsize=(7,3),
                            vmin=-15, vmax=15)

# %% [markdown]
# ### Pathways

# %%
signif_pws_per_cluster_kolf = pd.DataFrame(pw_acts_df_clusters_kolf.notna().sum(axis=1), 
                                           columns=["# significant pathways"])
signif_pws_per_cluster_kolf
# Out:
#             # significant pathways
# Cluster 0                        9
# Cluster 1                        7
# Cluster 2                        8
# Cluster 3                        8
# Cluster 4                        7
# Cluster 5                        7
# Cluster 6                        7
# Cluster 7                       10
# Cluster 8                       13
# Cluster 9                        6
# Cluster 10                       8
# Cluster 11                       3
# Cluster 12                       8

# %%
plot_tf_pw_activity_heatmap(pw_acts_df_clusters_kolf, 
                            title="KOLF PROGENy Inferred Pathway Activities",
                            xlabel="Leiden Cluster", ylabel="Pathway", figsize=(7,6),
                            cbar_size=0.5)

# %% [markdown]
# ## Leiden cluster 10

# %%
cl10_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl10_tf_kds]
cl10_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl10_tf_kd_labels)]
print(f"Enriched TFs per Cluster 10 TF KD")
cl10_kd_tf_acts.T.count()
# Out:
# Enriched TFs per Cluster 10 TF KD
# ADNP2 KD     1
# CHAMP1 KD    1
# DNMT1 KD     0
# E2F4 KD      0
# PITX3 KD     0
# SETDB1 KD    0
# VDR KD       1
# ZNF561 KD    0
# ZNF562 KD    0
# dtype: int64

# %%
plot_tf_pw_activity_heatmap(cl10_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 10 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(5,2),
                            xvals="kds", top=1, cbar_size=0.5)

# %% [markdown]
# ## Cluster 7

# %%
cl7_tf_kds = list(leiden_clusters_kolf["7"][leiden_clusters_kolf["7"].notna()])
print(f"{len(cl7_tf_kds)} TF KDs: {', '.join(cl7_tf_kds)}")
cl7_degs = cluster_deg_dict_kolf[7]
print(f"{len(cl7_degs)} cluster DEGs")
# Out:
# 13 TF KDs: ARID2, ATF4, FOXH1, JUNB, KLF4, MTERF1, RXRG, THAP12, ZBTB12, ZBTB14, ZNF142, ZNF358, ZNF787
# 90 cluster DEGs

# %%
cl7_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl7_tf_kds]
cl7_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl7_tf_kd_labels)]

# %%
plot_tf_pw_activity_heatmap(cl7_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 7 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(6,3),
                            xvals="kds", top=6, cbar_size=0.5)

# %% [markdown]
# ### KLF4

# %%
klf4_kd_degs = list(kd_deg_dict_kolf["KLF4"])
print(len(klf4_kd_degs))
# Out:
# 1

# %%
klf4_kd_wald_df = wald_df_kds_kolf.loc[["KLF4 KD"]].dropna(axis=1)
klf4_kd_wald_df
# Out:
#              A1BG  A1BG-AS1       A2M     A2ML1  A2ML1-AS1    A4GALT  \
# KLF4 KD  0.129013  0.269019  1.165708  0.494777   0.163839 -0.613672
#
#              AAAS      AACS   AACSP1     AADAT  ...      ZW10    ZWILCH  \
# KLF4 KD  0.400727  0.154693  0.22352  0.346613  ...  0.321297 -0.892539
#
#             ZWINT      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# KLF4 KD  0.066652 -0.840889 -0.518121  0.314963  0.168752  0.605855 -0.698189
#
#              ZZZ3
# KLF4 KD  0.772778
#
# [1 rows x 15988 columns]

# %%
klf4_kd_tf_acts = tf_acts_df_kds_kolf.loc[["KLF4 KD"]].dropna(axis=1)
klf4_kd_tf_acts
# Out:
#              RELA      TP53
# KLF4 KD -3.829713 -4.342441

# %%
plot_activity_barplot(klf4_kd_tf_acts, title="KOLF KLF4 KD - Inferred TF Activities",
                     figsize=(2,3), ylabel="Transcription Factor")

# %%
plot_tf_activity_network(grn=collectri, 
                         wald_df=klf4_kd_wald_df, 
                         tf_activities=klf4_kd_tf_acts,
                         sources=['RELA', 'TP53'],
                         targets=10,
                         figsize=(6,6),
                         size_node=20,
                         size_label=1,
                         title="KOLF KLF4 KD - TF Activity (All Target Genes)")

# %% [markdown]
# Pathway activity inference

# %%
klf4_kd_pathway_acts = pw_acts_df_kds_kolf.loc[["KLF4 KD"]].dropna(axis=1)
klf4_kd_pathway_acts
# Out:
#           Hypoxia      EGFR      MAPK
# KLF4 KD  3.889403 -4.917464 -2.651411

# %%
plot_activity_barplot(klf4_kd_pathway_acts, title="KOLF KLF4 KD - Inferred Pathway Activities",
                     figsize=(3,3), xmax=10, ylabel="Pathway")

# %% [markdown]
# ## Cluster 2

# %%
cl2_tf_kds = list(leiden_clusters_kolf["2"][leiden_clusters_kolf["2"].notna()])
print(f"{len(cl2_tf_kds)} TF KDs: {', '.join(cl2_tf_kds)}")
cl2_degs = cluster_deg_dict_kolf[2]
print(f"{len(cl2_degs)} cluster DEGs")
# Out:
# 18 TF KDs: BCL6B, CBX2, GLIS1, IKZF4, KLF14, L3MBTL3, LHX1, MESP2, PCGF2, PKNOX2, POGK, SP8, TCF7L1, ZNF22, ZNF324, ZNF382, ZNF596, ZNF614
# 34 cluster DEGs

# %%
tf_acts_df_clusters_kolf.loc[["Cluster 2"]].dropna(axis=1)
# Out:
#                 MYC     ZBTB4
# Cluster 2 -7.710453 -4.797347

# %%
plot_activity_barplot(tf_acts_df_clusters_kolf, cluster=2, figsize=(3,3), top=20,
                      title="KOLF Cluster 2 TF Activity Scores", ylabel="Transcription Factor")

# %%
cl2_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl2_tf_kds]
cl2_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl2_tf_kd_labels)]

# %%
plot_tf_pw_activity_heatmap(cl2_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 2 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(7,2),
                            xvals="kds", top=2)

# %% [markdown]
# ## Cluster 6

# %%
cl6_tf_kds = list(leiden_clusters_kolf["6"][leiden_clusters_kolf["6"].notna()])
print(f"{len(cl6_tf_kds)} TF KDs: {', '.join(cl6_tf_kds)}")
cl6_degs = cluster_deg_dict_kolf[6]
print(f"{len(cl6_degs)} cluster DEGs")
# Out:
# 14 TF KDs: ATF1, ESR1, ETV7, IRF9, LCORL, MBD3, RAG1, RORC, TFCP2L1, ZBTB21, ZFP1, ZNF17, ZNF697, ZSCAN5B
# 28 cluster DEGs

# %%
cl6_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl6_tf_kds]
cl6_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl6_tf_kd_labels)]

# %%
plot_tf_pw_activity_heatmap(cl6_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 6 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(6,2),
                            xvals="kds", top=2)

# %% [markdown]
# ## Cluster 0

# %%
cl0_tf_kds = list(leiden_clusters_kolf["0"][leiden_clusters_kolf["0"].notna()])
print(f"{len(cl0_tf_kds)} TF KDs: {', '.join(cl0_tf_kds)}")
cl0_degs = cluster_deg_dict_kolf[0]
print(f"{len(cl0_degs)} cluster DEGs")
# Out:
# 28 TF KDs: CREB3L3, DMBX1, ESRRG, FOXD3, HIC1, HNF1A, HOXA7, IRX5, NFKB2, NR5A1, OVOL3, PCGF6, SIX6, SP110, TBX19, ZBTB34, ZFP37, ZFP41, ZNF24, ZNF180, ZNF426, ZNF462, ZNF471, ZNF623, ZNF695, ZNF732, ZNF785, ZNF829
# 76 cluster DEGs

# %%
tf_acts_df_clusters_kolf.loc[["Cluster 0"]].dropna(axis=1)
# Out:
#                E2F4      HSF1      HSF2      KLF7        MYC     SALL2  \
# Cluster 0 -3.385629 -3.882529 -4.365313  3.513472 -13.247385  3.392642
#
#                 SP1    TEAD1     ZBTB4     ZNF76
# Cluster 0 -4.115345 -3.45188 -6.229181 -3.709091

# %%
plot_activity_barplot(tf_acts_df_clusters_kolf, cluster=0, figsize=(3,4), top=20,
                     title="KOLF CL0 - Inferred TF Activities", ylabel="Transcription Factor")

# %%
cl0_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl0_tf_kds]
cl0_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl0_tf_kd_labels)]

# %%
plot_tf_pw_activity_heatmap(cl0_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 0 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(8,4),
                            xvals="kds", top=8, min_activities_per_col=1)

# %% [markdown]
# ## Cluster 5

# %%
cl5_tf_kds = list(leiden_clusters_kolf["5"][leiden_clusters_kolf["5"].notna()])
print(f"{len(cl5_tf_kds)} TF KDs: {', '.join(cl5_tf_kds)}")
cl5_degs = cluster_deg_dict_kolf[5]
print(f"{len(cl5_degs)} cluster DEGs")
# Out:
# 14 TF KDs: ARID3B, LEF1, NKX2-4, RARG, RFX7, SMAD3, THAP6, TSHZ1, ZNF14, ZNF16, ZNF112, ZNF551, ZNF564, ZNF783
# 28 cluster DEGs

# %%
cl5_tf_kd_labels = [f"{tf_kd} KD" for tf_kd in cl5_tf_kds]
cl5_kd_tf_acts = tf_acts_df_kds_kolf[tf_acts_df_kds_kolf.index.isin(cl5_tf_kd_labels)]

# %%
plot_tf_pw_activity_heatmap(cl0_kd_tf_acts, sort_columns=True,
                            title="KOLF CollecTRI Cluster 5 Inferred TF Activities",
                            xlabel="TF KD", ylabel="Transcription Factor", figsize=(8,4),
                            xvals="kds", top=8, min_activities_per_col=1)
